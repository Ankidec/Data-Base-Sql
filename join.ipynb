-- %% [markdown]
-- - <span style="color: var(--vscode-foreground);">SQL JOIN</span>

-- %% [markdown]
-- 1\. cross join
--
-- 2.inner join
--
-- 3.

-- %%
--cross join between country and city
select 
    *
from country CROSS JOIN city;
-- Out:
-- (65400 row(s) affected)
-- Displaying Top 5000 rows.
-- Total execution time: 00:00:05.108
-- ...

-- %%
use sakila;
-- Out:
-- Commands completed successfully
-- Total execution time: 00:00:00.002

-- %%
select 
   city.city as city,
   country.country as country
from city CROSS JOIN
-- Out:
-- Total execution time: 00:00:00
-- : 1064 (42000): You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near '' at line 4

-- %%
-- inner join for city and country 
SELECT 
    city.city as city
    country.
